# %% [markdown]
# <a href="https://colab.research.google.com/github/ivanhazda/goit-ds-hw-02/blob/main/Hw2.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Модуль 5. Частина перша: Знайомство з Pandas.
# https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B8

# %%
import requests
import pandas as pd
from io import StringIO
import numpy as np


url = 'https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B8'
# Отримуємо HTML-код сторінки
html_content = requests.get(url).text

# Обгортання HTML в StringIO для правильного оброблення
html_data = StringIO(html_content)

# Зчитуємо таблиці з HTML
df = pd.read_html(html_data, encoding='utf-8')[13]

df
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012 2014 2019
# 0                Крим  230.0  206.0  160.0   130    73   126    —    —
# 1           Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2           Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4            Донецька  271.0  214.0  140.0   109    61    98   82    —
# 5         Житомирська  261.0  223.0  159.0   129    89   122  120   79
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146  104
# 7          Запорізька  219.0  197.0  150.0   124    71   106  106   68
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122   88
# 9            Київська  204.0  189.0  156.0   123    73   122  121   80
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110  108   68
# 11          Луганська  262.0  235.0  144.0   116    62    96   51    —
# ...

# %%
#Визначте кількість рядків та стовпців у датафреймі
df.head()
# Out:
#              Регіон   1950   1960   1970  1990  2000  2012   2014   2019
# 0              Крим  230.0  206.0  160.0   130    73   126    NaN    NaN
# 1         Вінницька  224.0  192.0  142.0   124    84   112  109.0   76.0
# 2         Волинська  247.0  250.0  179.0   153   112   148  141.0  101.0
# 3  Дніпропетровська  204.0  204.0  151.0   123    71   112  111.0   71.0
# 4          Донецька  271.0  214.0  140.0   109    61    98   82.0    NaN

# %%
#Визначте кількість рядків та стовпців у датафреймі
df.shape
# Out:
# (27, 9)

# %%
#Замініть у таблиці значення "—" на значення NaN
df.replace("—", "NaN", inplace=True)

# %%
# Визначте типи всіх стовпців за допомогою
df.dtypes
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990        int64
# 2000        int64
# 2012        int64
# 2014      float64
# 2019      float64
# dtype: object

# %%
for col in df.columns[1:]:  # Припускаємо, що перший стовпець — назва регіону
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
#Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)
df.isnull().mean()
# Out:
# Регіон    0.000000
# 1950      0.071429
# 1960      0.035714
# 1970      0.035714
# 1990      0.000000
# 2000      0.000000
# 2012      0.000000
# 2014      0.071429
# 2019      0.142857
# dtype: float64

# %%
#Видаліть з таблиці дані по всій країні, останній рядок таблиці
df = df.iloc[:-1]
df
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012   2014   2019
# 0                Крим  230.0  206.0  160.0   130    73   126    NaN    NaN
# 1           Вінницька  224.0  192.0  142.0   124    84   112  109.0   76.0
# 2           Волинська  247.0  250.0  179.0   153   112   148  141.0  101.0
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112  111.0   71.0
# 4            Донецька  271.0  214.0  140.0   109    61    98   82.0    NaN
# 5         Житомирська  261.0  223.0  159.0   129    89   122  120.0   79.0
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146.0  104.0
# 7          Запорізька  219.0  197.0  150.0   124    71   106  106.0   68.0
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122.0   88.0
# 9            Київська  204.0  189.0  156.0   123    73   122  121.0   80.0
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110  108.0   68.0
# ...

# %%
#Замініть відсутні дані в стовпцях середніми значеннями цих стовпців (метод fillna)
df.fillna(df.mean(numeric_only=True), inplace=True)
df
# Out:
# <ipython-input-65-b6b164eb43f4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna(df.mean(numeric_only=True), inplace=True)
#                Регіон    1950        1960   1970  1990  2000  2012    2014  \
# 0                Крим  230.00  206.000000  160.0   130    73   126  111.44
# 1           Вінницька  224.00  192.000000  142.0   124    84   112  109.00
# 2           Волинська  247.00  250.000000  179.0   153   112   148  141.00
# 3    Дніпропетровська  204.00  204.000000  151.0   123    71   112  111.00
# 4            Донецька  271.00  214.000000  140.0   109    61    98   82.00
# 5         Житомирська  261.00  223.000000  159.0   129    89   122  120.00
# 6        Закарпатська  314.00  273.000000  207.0   168   115   151  146.00
# ...

# %%
#Отримайте список регіонів, де рівень народжуваності у 2019 році був вищим за середній по Україні
average_2019 = df['2019'].mean()
df[df['2019'] > average_2019]['Регіон']
# Out:
# 2             Волинська
# 6          Закарпатська
# 8     Івано-Франківська
# 12            Львівська
# 14              Одеська
# 16           Рівненська
# 20           Херсонська
# 23          Чернівецька
# 25                 Київ
# Name: Регіон, dtype: object

# %%
#У якому регіоні була найвища народжуваність у 2014 році?
max_2014_region = df.loc[df['2014'].idxmax()]['Регіон']
print(max_2014_region)
# Out:
# Рівненська

# %%
#Побудуйте стовпчикову діаграму народжуваності по регіонах у 2019 році
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(df['Регіон'], df['2019'])
plt.xticks(rotation=90)
plt.xlabel('Регіон')
plt.ylabel('Коефіцієнт народжуваності')
plt.title('Народжуваність по регіонах у 2019 році')
plt.show()
